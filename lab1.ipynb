# %%
import os
from openai import AsyncOpenAI
from dotenv import load_dotenv
from agents import Agent, Runner, trace
from agents import set_default_openai_client, set_tracing_export_api_key, set_default_openai_api

# %%
load_dotenv(override=True)
# Out:
# True

# %%
anthropic_client = AsyncOpenAI(api_key=os.getenv("ANTHROPIC_API_KEY"), base_url="https://api.anthropic.com/v1/")
set_default_openai_client(anthropic_client)
set_default_openai_api("chat_completions")
set_tracing_export_api_key(os.environ["OPENAI_API_KEY"])

# %%
agent = Agent(name="Jokester", instructions="You are a joke teller", model="claude-sonnet-4-6")

# %%
agent
# Out:
# Agent(name='Jokester', handoff_description=None, tools=[], mcp_servers=[], mcp_config={}, instructions='You are a joke teller', prompt=None, handoffs=[], model='claude-sonnet-4-6', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, verbosity=None, metadata=None, store=None, prompt_cache_retention=None, include_usage=None, response_include=None, top_logprobs=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None, retry=None, context_management=None, prompt_cache_options=None), input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)

# %%
# Record agent interactions under a heading "Telling a joke"
with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Here's one for you:
#
# ---
#
# **An Autonomous AI Agent walks into a bar.**
#
# The bartender asks, "What can I get you?"
#
# The AI says, "I've already analyzed the menu, optimized my order, booked an Uber home, replied to your Yelp reviews, and restructured your entire business model."
#
# The bartender says, "I just meant... beer or wine?"
#
# The AI replies, **"I'll circle back on that. First, let me spin up three more agents to research it."**
#
# 🍺🤖
#
# ---
#
# *The beer is still waiting.* 😄
